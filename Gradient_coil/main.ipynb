# %%
import numpy as np
from mayavi import mlab
import trimesh

from bfieldtools.coil_optimize import optimize_streamfunctions
from bfieldtools.mesh_conductor import MeshConductor

from bfieldtools.viz import plot_data_on_vertices
from bfieldtools import sphtools

# %%
import os
os.getcwd()
# Out:
# 'f:\\Programmazione\\MiniMRI\\Gradient_Coil'

# %%
mlab.init_notebook('png')
# Out:
# Notebook initialized with png backend.

# %%
coil_mesh = trimesh.load("./meshes/two_size_ellipse_multires_UHR.stl")
# coil_mesh.apply_transform()
# coil_mesh.apply_scale(100)
coil = MeshConductor(
    mesh_obj=coil_mesh, 
    fix_normals=True,
    basis_name='suh', 
    N_suh=100, 
    sph_radius=15,
    sph_normalization="energy",
    )

# shield_mesh = trimesh.load("cylinder_LR.stl")
# coil.apply_scale(1.1)

# shield = MeshConductor(mesh_obj=shield_mesh, process=True, fix_normals=True, basis_name="vertex")
# Out:
# Calculating surface harmonics expansion...
# Computing the laplacian matrix...
# Computing the mass matrix...

# %%
sidelength = 30
n = 10
xx = np.linspace(-sidelength / 2, sidelength / 2, n)
yy = np.linspace(-sidelength / 2, sidelength / 2, n)
zz = np.linspace(-sidelength / 2, sidelength / 2, n)
X, Y, Z = np.meshgrid(xx, yy, zz, indexing="ij")

x = X.ravel()
y = Y.ravel()
z = Z.ravel()

target_points = np.array([x, y, z]).T

# Turn cube into sphere by rejecting points "in the corners"
target_points = (
    target_points[np.linalg.norm(target_points, axis=1) < sidelength / 2]
)

# %%
f = mlab.figure(bgcolor=(1, 1, 1), fgcolor=(.5, .5, .5))
mlab.points3d(*target_points.T)
coil.plot_mesh(opacity=0.2, figure=f)
# shield.plot_mesh(opacity=0.2, figure=f)
# Out:
# <img src="data:image/png;base64,..." alt="PNG image"></img>

# %%
# lmax = 2
# alm = np.zeros((lmax * (lmax + 2),))
# blm = np.zeros((lmax * (lmax + 2),))

alm = np.zeros((coil.opts["N_sph"]* (coil.opts["N_sph"]+2),))
blm = np.zeros((coil.opts["N_sph"]* (coil.opts["N_sph"]+2),))
# Set one specific component to one
blm[6] += 1


sphfield = sphtools.field(target_points, alm, blm, coil.opts["N_sph"])
target_field = sphfield / np.max(sphfield[:, 0])

field_y = target_field.copy()

field_y[:, 0] = 0
field_y[:, 2] = 0

mlab.clf()
f = mlab.figure(bgcolor=(.1, .1, .1), fgcolor=(1, 1, 1))
mlab.quiver3d(*target_points.T, *field_y.T, figure=f)
coil.plot_mesh(opacity=0.2, figure=f)
f.scene.isometric_view()
f.scene.camera.zoom(3)

# mlab.view(90, 180)
f
# Out:
# <img src="data:image/png;base64,..." alt="PNG image"></img>

# %%
import mosek


target_spec = {
    "coupling": coil.sph_couplings[1],
    "abs_error": 0.01,
    "target": blm,
}

coil.s, prob = optimize_streamfunctions(
    coil,
    [target_spec],
    objective="minimum_inductive_energy",
    solver="MOSEK",
    solver_opts={"mosek_params": {mosek.iparam.num_threads: 8}},
)
# Out:
# Computing coupling matrices
# l = 1 computed
# l = 2 computed
# l = 3 computed
# l = 4 computed
# l = 5 computed
# Computing the inductance matrix...
# Computing self-inductance matrix using rough quadrature (degree=2).              For higher accuracy, set quad_degree to 4 or more.
# Estimating 146239 MiB required for 7316 by 7316 vertices...
# Computing inductance matrix in 260 chunks (12029 MiB memory free),              when approx_far=True using more chunks is faster...
# Computing triangle-coupling matrix
# Inductance matrix computation took 158.42 seconds.
# Passing problem to solver...
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Nov 20 11:29:26 PM: Your problem has 100 variables, 2 constraints, and 0 parameters.
# (CVXPY) Nov 20 11:29:26 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 20 11:29:26 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 20 11:29:26 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 20 11:29:26 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Nov 20 11:29:26 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Nov 20 11:29:26 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 20 11:29:26 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 20 11:29:26 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 20 11:29:26 PM: Applying reduction MOSEK
# (CVXPY) Nov 20 11:29:26 PM: Finished problem compilation (took 6.009e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 20 11:29:26 PM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Nov 20 11:29:26 PM: Problem
# (CVXPY) Nov 20 11:29:26 PM:   Name                   :
# (CVXPY) Nov 20 11:29:26 PM:   Objective sense        : maximize
# (CVXPY) Nov 20 11:29:26 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Nov 20 11:29:26 PM:   Constraints            : 101
# (CVXPY) Nov 20 11:29:26 PM:   Affine conic cons.     : 0
# (CVXPY) Nov 20 11:29:26 PM:   Disjunctive cons.      : 0
# (CVXPY) Nov 20 11:29:26 PM:   Cones                  : 1
# (CVXPY) Nov 20 11:29:26 PM:   Scalar variables       : 172
# (CVXPY) Nov 20 11:29:26 PM:   Matrix variables       : 0
# (CVXPY) Nov 20 11:29:26 PM:   Integer variables      : 0
# (CVXPY) Nov 20 11:29:26 PM:
# (CVXPY) Nov 20 11:29:26 PM: Optimizer started.
# (CVXPY) Nov 20 11:29:26 PM: Presolve started.
# (CVXPY) Nov 20 11:29:26 PM: Linear dependency checker started.
# (CVXPY) Nov 20 11:29:26 PM: Linear dependency checker terminated.
# (CVXPY) Nov 20 11:29:26 PM: Eliminator started.
# (CVXPY) Nov 20 11:29:26 PM: Freed constraints in eliminator : 0
# (CVXPY) Nov 20 11:29:26 PM: Eliminator terminated.
# (CVXPY) Nov 20 11:29:26 PM: Eliminator - tries                  : 1                 time                   : 0.00
# (CVXPY) Nov 20 11:29:26 PM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Nov 20 11:29:26 PM: Lin. dep.  - number                 : 0
# (CVXPY) Nov 20 11:29:26 PM: Presolve terminated. Time: 0.00
# (CVXPY) Nov 20 11:29:26 PM: Problem
# (CVXPY) Nov 20 11:29:26 PM:   Name                   :
# (CVXPY) Nov 20 11:29:26 PM:   Objective sense        : maximize
# (CVXPY) Nov 20 11:29:26 PM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Nov 20 11:29:26 PM:   Constraints            : 101
# (CVXPY) Nov 20 11:29:26 PM:   Affine conic cons.     : 0
# (CVXPY) Nov 20 11:29:26 PM:   Disjunctive cons.      : 0
# (CVXPY) Nov 20 11:29:26 PM:   Cones                  : 1
# (CVXPY) Nov 20 11:29:26 PM:   Scalar variables       : 172
# (CVXPY) Nov 20 11:29:26 PM:   Matrix variables       : 0
# (CVXPY) Nov 20 11:29:26 PM:   Integer variables      : 0
# (CVXPY) Nov 20 11:29:26 PM:
# (CVXPY) Nov 20 11:29:26 PM: Optimizer  - threads                : 8
# (CVXPY) Nov 20 11:29:26 PM: Optimizer  - solved problem         : the primal
# (CVXPY) Nov 20 11:29:26 PM: Optimizer  - Constraints            : 101
# (CVXPY) Nov 20 11:29:26 PM: Optimizer  - Cones                  : 1
# (CVXPY) Nov 20 11:29:26 PM: Optimizer  - Scalar variables       : 172               conic                  : 102
# (CVXPY) Nov 20 11:29:26 PM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Nov 20 11:29:26 PM: Factor     - setup time             : 0.02              dense det. time        : 0.00
# (CVXPY) Nov 20 11:29:26 PM: Factor     - ML order time          : 0.00              GP order time          : 0.00
# (CVXPY) Nov 20 11:29:26 PM: Factor     - nonzeros before factor : 5151              after factor           : 5151
# (CVXPY) Nov 20 11:29:26 PM: Factor     - dense dim.             : 0                 flops                  : 9.87e+05
# (CVXPY) Nov 20 11:29:26 PM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Nov 20 11:29:26 PM: 0   1.0e+00  5.1e+00  2.0e+00  0.00e+00   -1.000000000e+00  0.000000000e+00   1.0e+00  0.03
# (CVXPY) Nov 20 11:29:26 PM: 1   2.6e-01  1.3e+00  3.6e-01  -2.54e-01  4.302608645e-01   7.021831726e-01   2.6e-01  0.08
# (CVXPY) Nov 20 11:29:26 PM: 2   3.8e-02  1.9e-01  7.2e-03  1.01e+00   1.667762331e+00   1.752384123e+00   3.8e-02  0.08
# (CVXPY) Nov 20 11:29:26 PM: 3   2.1e-03  1.1e-02  1.9e-04  1.32e+00   1.707836882e+00   1.710025183e+00   2.1e-03  0.08
# (CVXPY) Nov 20 11:29:26 PM: 4   1.4e-06  7.3e-06  1.7e-09  1.10e+00   1.712952386e+00   1.712954764e+00   1.4e-06  0.08
# (CVXPY) Nov 20 11:29:26 PM: 5   6.5e-10  3.3e-09  1.6e-14  1.00e+00   1.712957160e+00   1.712957161e+00   6.5e-10  0.08
# (CVXPY) Nov 20 11:29:26 PM: Optimizer terminated. Time: 0.12
# (CVXPY) Nov 20 11:29:26 PM:
# (CVXPY) Nov 20 11:29:26 PM:
# (CVXPY) Nov 20 11:29:26 PM: Interior-point solution summary
# (CVXPY) Nov 20 11:29:26 PM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Nov 20 11:29:26 PM:   Solution status : OPTIMAL
# (CVXPY) Nov 20 11:29:26 PM:   Primal.  obj: 1.7129571597e+00    nrm: 2e+01    Viol.  con: 3e-10    var: 3e-07    cones: 0e+00
# (CVXPY) Nov 20 11:29:26 PM:   Dual.    obj: 1.7129571608e+00    nrm: 4e+00    Viol.  con: 0e+00    var: 6e-10    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 20 11:29:26 PM: Problem status: optimal
# (CVXPY) Nov 20 11:29:26 PM: Optimal value: 1.713e+00
# (CVXPY) Nov 20 11:29:26 PM: Compilation took 6.009e-02 seconds
# (CVXPY) Nov 20 11:29:26 PM: Solver (including time spent in interface) took 1.700e-01 seconds

# %%
f = coil.plot_mesh(opacity=0.2)
loops = coil.s.discretize(N_contours=12)
loops.plot_loops(figure=f)
# Out:
# Processing contour, value: -2470.086535276389
# Processing contour, value: -2020.982573120743
# Processing contour, value: -1571.878610965097
# Processing contour, value: -1122.7746488094513
# Processing contour, value: -673.6706866538052
# Processing contour, value: -224.5667244981596
# Processing contour, value: 224.53723765748646
# Processing contour, value: 673.6411998131325
# Processing contour, value: 1122.7451619687781
# Processing contour, value: 1571.8491241244237
# Processing contour, value: 2020.9530862800702
# Processing contour, value: 2470.057048435716
# <img src="data:image/png;base64,..." alt="PNG image"></img>

# %%
loops_dict = loops.to_dict()

paths = loops_dict['entities']
vertices = loops_dict['vertices']

vertices_cyl = []

radius = 35
L = 10

for v in vertices: # X axis cilynder
    x, y, z = v
    theta = np.arctan2(y, z)

    l = theta*radius
    # vertices_cyl.append((l, x, 0))
    vertices_cyl.append((x, y, 0))

path = []
for p in paths:
    line = p['points']
    for i in range(len(line)):
        if i == len(line)-1:
            path.append((line[i], line[0]))
        else:
            path.append((line[i], line[i+1]))

# %%
def spline_length(spl, closed=False):
    u = np.linspace(0, 1, 100)
    I = 0
    add_cl = 0 if closed else 0
    for i in range(len(u)-add_cl):
        if closed and i == len(u)-1:
            I += np.linalg.norm(np.array(splev(u[i], spl)) - np.array(splev(u[0], spl)))
        else:
            I += np.linalg.norm(np.array(splev(u[i+1], spl)) - np.array(splev(u[i], spl)))
    
    return I

# %%
from matplotlib import pyplot as plt
from matplotlib import cm
from scipy.interpolate import splprep, splev

col = plt.cm.viridis(np.linspace(0, 1, int(len(paths)/4)))

tl = []
tr = []
bl = []
br = []

for j in range(int(len(paths)/4)):
    span = int(len(paths)/2)
    line = np.array([list(vertices_cyl[i]) for i in paths[j*2]['points']])
    tl.append(line)
    # plt.plot(*line.T, alpha=0.3, color=col[j])
    line = np.array([list(vertices_cyl[i]) for i in paths[j*2+span]['points']])
    tr.append(line)
    # plt.plot(*line.T, alpha=0.3, color=col[j])
    line = np.array([list(vertices_cyl[i]) for i in paths[j*2+1]['points']])
    bl.append(line)
    # plt.plot(*line.T, alpha=0.3, color=col[j])
    line = np.array([list(vertices_cyl[i]) for i in paths[j*2+1+span]['points']])
    br.append(line)

    # plt.plot(*line.T, alpha=0.3, color=col[j])

# plt.xlim([-np.pi*radius, np.pi*radius])
# plt.ylim([-L/2, L/2])
# plt.show()

# %% [markdown]
# ## Refactor contours with equally spaced points

# %%
new_vertices = []
new_edges = []
tot_len = 0
index = 0

res = 1
closed = True
for line in tl+tr+br+bl:
    spl, _ = splprep(line.T, s=0)
    l = spline_length(spl, True)
    tot_len+=l
    points = np.linspace(0, 1, int(l/res))

    for i, p in enumerate(points):
        
        vert = tuple(list(np.array(splev(p, spl))))
        new_vertices.append(vert)
        
        if i > 0:
            new_edges.append((index-1, index))
        index+=1

# print(line)
print(new_edges[-1])
print(tot_len)
plt.show()
# Out:
# (4306, 4307)
# 4321.729634102749

# %%
new_vertices = np.array(new_vertices)
new_edges = np.array(new_edges, dtype=np.int32)

with open('vertices.txt', 'w') as f:
   np.savetxt(f, new_vertices)

with open('edges.txt', 'w') as f:
   np.savetxt(f, new_edges)
